# %%
import pandas as pd
import numpy as np
import re

# %%
gps = pd.read_csv("googleplaystore.csv")
gps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# ### Convert the app sizes to a number

# %%
gps['Size'] = gps['Size'].replace('Varies with device', np.nan) # here I set 'Varies with device' into NaN Value in order 
#to make easier the transformation

gps['Size'] = (gps.Size.replace([r'[kM+]+$',','], '', regex=True).astype(float) *
            gps.Size.str.extract(r'[\d\.]+([kM]+)', expand=False).
            fillna(0).replace(['k','M'], [10**3, 10**6]).astype(float))

# %%
gps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews        Size     Installs  Type Price Content Rating  \
# 0     159  19000000.0      10,000+  Free     0       Everyone
# 1     967  14000000.0     500,000+  Free     0       Everyone
# 2   87510   8700000.0   5,000,000+  Free     0       Everyone
# 3  215644  25000000.0  50,000,000+  Free     0           Teen
# 4     967   2800000.0     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# ### Convert the number of installs in number

# %%
gps['Installs'] = gps['Installs'].replace(r'[^0-9]','',regex=True)
#gps['Installs'] = gps['Installs'].replace(r'[^0-9]','',regex=True).astype(int) 

gps['Installs'] = pd.to_numeric(gps['Installs'],errors = 'coerce')

# %%
gps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews        Size    Installs  Type Price Content Rating  \
# 0     159  19000000.0     10000.0  Free     0       Everyone
# 1     967  14000000.0    500000.0  Free     0       Everyone
# 2   87510   8700000.0   5000000.0  Free     0       Everyone
# 3  215644  25000000.0  50000000.0  Free     0           Teen
# 4     967   2800000.0    100000.0  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# ### Transform “Varies with device” into a missing value

# %%
gps2 = gps.replace('Varies with device', np.nan)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters       ART_AND_DESIGN
# 12                        Tattoo Name On My Photo Editor       ART_AND_DESIGN
# 13                                 Mandala Coloring Book       ART_AND_DESIGN
# 14       3D Color Pixel by Number - Sandbox Art Coloring       ART_AND_DESIGN
# 15                       Learn To Draw Kawaii Characters       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 17                              350 Diy Room Decor Ideas       ART_AND_DESIGN
# 18                         FlipaClip - Cartoon animation       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# 20                           Logo Maker - Small Business       ART_AND_DESIGN
# 21             Boys Photo Editor - Six Pack & Men's Suit       ART_AND_DESIGN
# 22               Superheroes Wallpapers | 4K Backgrounds       ART_AND_DESIGN
# 23                                Mcqueen Coloring pages       ART_AND_DESIGN
# 24                           HD Mickey Minnie Wallpapers       ART_AND_DESIGN
# 25                            Harley Quinn wallpapers HD       ART_AND_DESIGN
# 26                         Colorfit - Drawing & Coloring       ART_AND_DESIGN
# 27                                 Animated Photo Editor       ART_AND_DESIGN
# 28                                 Pencil Sketch Drawing       ART_AND_DESIGN
# 29                       Easy Realistic Drawing Tutorial       ART_AND_DESIGN
# ...                                                  ...                  ...
# 
# 9              Art & Design;Creativity        July 3, 2018         2.8
# 10                        Art & Design    October 27, 2017       1.0.4
# 11                        Art & Design       July 31, 2018      1.0.15
# 12                        Art & Design       April 2, 2018         3.8
# 13                        Art & Design       June 26, 2018       1.0.4
# 14                        Art & Design      August 3, 2018       1.2.3
# 15                        Art & Design        June 6, 2018         NaN
# 16                        Art & Design       July 31, 2018         3.1
# 17                        Art & Design    November 7, 2017         1.0
# 18                        Art & Design      August 3, 2018       2.2.5
# 19                        Art & Design       July 30, 2018       5.5.4
# 20                        Art & Design      April 20, 2018         4.0
# 21                        Art & Design      March 20, 2018         1.1
# 22                        Art & Design       July 12, 2018     2.2.6.2
# 23     Art & Design;Action & Adventure       March 7, 2018       1.0.0
# 24                        Art & Design        July 7, 2018       1.1.3
# 25                        Art & Design      April 25, 2018         1.5
# 26             Art & Design;Creativity    October 11, 2017       1.0.8
# 27                        Art & Design      March 21, 2018        1.03
# 28                        Art & Design       July 12, 2018         6.0
# 29                        Art & Design     August 22, 2017         1.0
# ...                                ...                 ...         ...
# 10811                  Auto & Vehicles       July 24, 2018       1.3.6
# 10812                        Education       June 13, 2018      2.0.20
# 10813                         Business       July 17, 2018      2.1.10
# 10814                    Entertainment        June 3, 2015       1.3.1
# 10815                Books & Reference       July 19, 2018     7.0.4.6
# 10816                         Business      August 6, 2018       2.1.8
# 10817                            Tools    October 30, 2015  1.0.612928
# 10818                          Finance        May 19, 2016         2.3
# 10819                Books & Reference      August 5, 2017       0.3.4
# 10820                        Education       June 27, 2018       3.8.0
# 10821                    Entertainment        May 29, 2018         1.0
# 10822                     Productivity    December 1, 2017           1
# 10823          Video Players & Editors      April 22, 2018         1.0
# 10824                          Medical       July 31, 2018       2.2.2
# 10825                           Social    February 2, 2018         1.0
# 10826                           Social      March 23, 2018         NaN
# 10827                        Education       June 13, 2018      2.0.20
# 10828                           Comics        May 15, 2017       2.0.1
# 10829                Books & Reference       June 19, 2016        2.96
# 10830                 News & Magazines    January 20, 2014         1.5
# 10831                Maps & Navigation       June 13, 2018   2.0.148.0
# 10832                          Weather   February 16, 2014         6.0
# 10833                Books & Reference      March 23, 2014         0.8
# 10834                        Education       June 18, 2017       1.0.0
# 10835                         Business  September 29, 2016       1.1.5
# 10836                        Education       July 25, 2017        1.48
# 10837                        Education        July 6, 2018         1.0
# 10838                          Medical    January 20, 2017         1.0
# 10839                Books & Reference    January 19, 2015         NaN
# 10840                        Lifestyle       July 25, 2018         NaN
#
#         Android Ver
# 0      4.0.3 and up
# 1      4.0.3 and up
# 2      4.0.3 and up
# 3        4.2 and up
# 4        4.4 and up
# 5        2.3 and up
# 6      4.0.3 and up
# 7        4.2 and up
# 8        3.0 and up
# 9      4.0.3 and up
# 10       4.1 and up
# 11       4.0 and up
# 12       4.1 and up
# 13       4.4 and up
# 14       2.3 and up
# 15       4.2 and up
# 16       4.1 and up
# 17       2.3 and up
# 18     4.0.3 and up
# 19       4.1 and up
# 20       4.1 and up
# 21     4.0.3 and up
# 22     4.0.3 and up
# 23       4.1 and up
# 24       4.1 and up
# 25       3.0 and up
# 26     4.0.3 and up
# 27     4.0.3 and up
# 28       2.3 and up
# 29       2.3 and up
# ...             ...
# 10811   4.4W and up
# 10812  4.0.3 and up
# 10813    4.1 and up
# 10814    3.0 and up
# 10815    4.2 and up
# 10816    4.1 and up
# 10817    5.0 and up
# 10818    2.2 and up
# 10819    4.1 and up
# 10820    4.1 and up
# 10821  4.0.3 and up
# 10822    4.4 and up
# 10823  4.0.3 and up
# 10824    4.4 and up
# 10825    4.0 and up
# 10826           NaN
# 10827  4.0.3 and up
# 10828    4.0 and up
# 10829    4.1 and up
# 10830    1.6 and up
# 10831    4.0 and up
# 10832    2.1 and up
# 10833    2.2 and up
# 10834    4.1 and up
# 10835    4.0 and up
# 10836    4.1 and up
# 10837    4.1 and up
# 10838    2.2 and up
# 10839           NaN
# 10840           NaN
#
# [10841 rows x 13 columns]

# %% [markdown]
# ### Convert Current Ver and Android Ver into a dotted number (e.g. 4.0.3 or 4.2)

# %%
gps2['Current Ver'] = gps2['Current Ver'].str.replace(r'[^0-9\.]','', regex = True)
gps2['Android Ver'] = gps2['Android Ver'].str.replace(r'[^0-9\.]','', regex = True)

# %%
gps2.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews        Size    Installs  Type Price Content Rating  \
# 0     159  19000000.0     10000.0  Free     0       Everyone
# 1     967  14000000.0    500000.0  Free     0       Everyone
# 2   87510   8700000.0   5000000.0  Free     0       Everyone
# 3  215644  25000000.0  50000000.0  Free     0           Teen
# 4     967   2800000.0    100000.0  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver Android Ver
# 0               Art & Design   January 7, 2018       1.0.0       4.0.3
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0       4.0.3
# 2               Art & Design    August 1, 2018       1.2.4       4.0.3
# 3               Art & Design      June 8, 2018         NaN         4.2
# 4    Art & Design;Creativity     June 20, 2018         1.1         4.4

# %% [markdown]
# ### Remove the duplicates

# %%
print(len(gps))
# Out:
# 10841

# %%
#to remove duplicates using pandas:
gps2.drop_duplicates(subset = 'App',keep = 'first', inplace = True) 
gps2 = gps2.reset_index()
gps2=gps2.drop(columns = 'index')

# %%
print(len(gps2)
# Out:
# 9660

# %% [markdown]
# ### For each category, compute the number of apps

# %%
categories = gps2.groupby(['Category'], as_index=False)['App'].count() 
categories
# Out:
#                Category   App
# 0        ART_AND_DESIGN    64
# 1     AUTO_AND_VEHICLES    85
# 2                BEAUTY    53
# 3   BOOKS_AND_REFERENCE   222
# 4              BUSINESS   420
# 5                COMICS    56
# 6         COMMUNICATION   315
# 7                DATING   171
# 8             EDUCATION   119
# 9         ENTERTAINMENT   102
# 10               EVENTS    64
# 11               FAMILY  1832
# 12              FINANCE   345
# 13       FOOD_AND_DRINK   112
# 14                 GAME   959
# 15   HEALTH_AND_FITNESS   288
# 16       HOUSE_AND_HOME    74
# 17   LIBRARIES_AND_DEMO    84
# 18            LIFESTYLE   369
# 19  MAPS_AND_NAVIGATION   131
# 20              MEDICAL   395
# 21   NEWS_AND_MAGAZINES   254
# 22            PARENTING    60
# 23      PERSONALIZATION   376
# 24          PHOTOGRAPHY   281
# 25         PRODUCTIVITY   374
# 26             SHOPPING   202
# 27               SOCIAL   239
# 28               SPORTS   325
# 29                TOOLS   827
# 30     TRAVEL_AND_LOCAL   219
# 31        VIDEO_PLAYERS   163
# 32              WEATHER    79

# %%
gps2.loc[9300]
gps2=gps2.drop(gps2.index[9300])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 9300
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-126-8eddf4e96082> in <module>()
# ----> 1 gps2.loc[9300]
#       2 gps2=gps2.drop(gps2.index[9300])
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     139             raise IndexingError('no slices here, handle elsewhere')
#     140
# --> 141         return self.obj._xs(label, axis=axis)
#     142
#     143     def _get_loc(self, key, axis=None):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3583                                                       drop_level=drop_level)
#    3584         else:
# -> 3585             loc = self.index.get_loc(key)
#    3586
#    3587             if isinstance(loc, np.ndarray):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
# -> 2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2659         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2660         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 9300

# %% [markdown]
# ### For each category, compute the average rating

# %%
Categories_rating_mean = gps2.groupby(['Category'], as_index=False)['Rating'].mean()
Categories_rating_mean
# Out:
#                Category    Rating
# 0        ART_AND_DESIGN  4.357377
# 1     AUTO_AND_VEHICLES  4.190411
# 2                BEAUTY  4.278571
# 3   BOOKS_AND_REFERENCE  4.344970
# 4              BUSINESS  4.098479
# 5                COMICS  4.181481
# 6         COMMUNICATION  4.121484
# 7                DATING  3.970149
# 8             EDUCATION  4.364407
# 9         ENTERTAINMENT  4.135294
# 10               EVENTS  4.435556
# 11               FAMILY  4.179664
# 12              FINANCE  4.115563
# 13       FOOD_AND_DRINK  4.172340
# 14                 GAME  4.247368
# 15   HEALTH_AND_FITNESS  4.243033
# 16       HOUSE_AND_HOME  4.150000
# 17   LIBRARIES_AND_DEMO  4.178125
# 18            LIFESTYLE  4.093355
# 19  MAPS_AND_NAVIGATION  4.036441
# 20              MEDICAL  4.166552
# 21   NEWS_AND_MAGAZINES  4.121569
# 22            PARENTING  4.300000
# 23      PERSONALIZATION  4.332215
# 24          PHOTOGRAPHY  4.157414
# 25         PRODUCTIVITY  4.183389
# 26             SHOPPING  4.230000
# 27               SOCIAL  4.247291
# 28               SPORTS  4.216154
# 29                TOOLS  4.039554
# 30     TRAVEL_AND_LOCAL  4.069519
# 31        VIDEO_PLAYERS  4.044595
# 32              WEATHER  4.243056

# %% [markdown]
# ### Create two dataframes: one for the genres and one bridging apps and genres. So that, for instance, the app Pixel Draw - Number Art Coloring Book appears twice in the bridging table, once for Art & Design, once for Creativity

# %%
new_df = pd.DataFrame(gps2.Genres.str.split(';').tolist()).stack()

new_df.drop_duplicates(keep = 'first', inplace = True)

new_df = new_df.reset_index()

new_df = new_df.drop(columns=['level_0','level_1'])

new_df.columns=['Genres']

new_df.head()
# Out:
#                Genres
# 0        Art & Design
# 1        Pretend Play
# 2          Creativity
# 3  Action & Adventure
# 4     Auto & Vehicles

# %%
bridge =  pd.DataFrame (gps2.Genres.str.split(';').tolist(),gps2.App).stack()

bridge = bridge.reset_index()

bridge = bridge.drop(columns=['level_1'])

bridge.columns = ['App','Genre']

bridge.head()
# Out:
#                                                  App         Genre
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art & Design
# 1                                Coloring book moana  Art & Design
# 2                                Coloring book moana  Pretend Play
# 3  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art & Design
# 4                              Sketch - Draw & Paint  Art & Design

# %% [markdown]
# ### For each genre, create a new column of the original dataframe. The new columns must have boolean values (True if the app has a given genre)

# %%
gps3= gps2['Genres'].str.split(";", expand = True) #splits without stacking
gps3.head()
# Out:
#               0             1
# 0  Art & Design          None
# 1  Art & Design  Pretend Play
# 2  Art & Design          None
# 3  Art & Design          None
# 4  Art & Design    Creativity

# %%
gps_copy1 = gps2.copy() #creates two copy of the original dataframe
gps_copy2 = gps2.copy()
gps_copy1['Genres']=gps3[0] #adds to one copy the first column of gps3, whre there are the "main" genres
gps_copy2['Genres']= gps3[1] #adds to the other copy the "second genre"

gps_copy2 = gps_copy2.dropna(subset= ['Genres']) #eliminates the rows of the second copy where Genre is None

gps4 = pd.concat([gps_copy1,gps_copy2]) #concatenation
gps4= gps4.reset_index() #resetting index
gps4=gps4.drop(columns='index')
gps4
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# 5                             Paper flowers instructions  ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN
# 7                                       Infinite Painter  ART_AND_DESIGN
# 8                                   Garden Coloring Book  ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun  ART_AND_DESIGN
# 10                               Text on Photo - Fonteee  ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters  ART_AND_DESIGN
# 12                        Tattoo Name On My Photo Editor  ART_AND_DESIGN
# 13                                 Mandala Coloring Book  ART_AND_DESIGN
# 14       3D Color Pixel by Number - Sandbox Art Coloring  ART_AND_DESIGN
# 15                       Learn To Draw Kawaii Characters  ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes  ART_AND_DESIGN
# 17                              350 Diy Room Decor Ideas  ART_AND_DESIGN
# 18                         FlipaClip - Cartoon animation  ART_AND_DESIGN
# 19                                          ibis Paint X  ART_AND_DESIGN
# 10045     4.2    3478         NaN    500000.0  Free      0       Everyone
# 10046     3.9   60097  19000000.0   1000000.0  Free      0       Everyone
# 10047     4.3   12919  94000000.0   1000000.0  Free      0       Everyone
# 10048     3.9    2249         NaN    500000.0  Free      0       Everyone
# 10049     4.3   30668  33000000.0   5000000.0  Free      0       Everyone
# 10050     4.2   38473  23000000.0  10000000.0  Free      0       Everyone
# 10051     4.4  129542  63000000.0   1000000.0  Free      0       Everyone
#
#                    Genres        Last Updated   Current Ver Android Ver
# 0            Art & Design     January 7, 2018         1.0.0       4.0.3
# 1            Art & Design    January 15, 2018         2.0.0       4.0.3
# 2            Art & Design      August 1, 2018         1.2.4       4.0.3
# 3            Art & Design        June 8, 2018           NaN         4.2
# 4            Art & Design       June 20, 2018           1.1         4.4
# 5            Art & Design      March 26, 2017           1.0         2.3
# 6            Art & Design      April 26, 2018           1.1       4.0.3
# 7            Art & Design       June 14, 2018      6.1.61.1         4.2
# 8            Art & Design  September 20, 2017         2.9.2         3.0
# 9            Art & Design        July 3, 2018           2.8       4.0.3
# 10           Art & Design    October 27, 2017         1.0.4         4.1
# 11           Art & Design       July 31, 2018        1.0.15         4.0
# 12           Art & Design       April 2, 2018           3.8         4.1
# 13           Art & Design       June 26, 2018         1.0.4         4.4
# 14           Art & Design      August 3, 2018         1.2.3         2.3
# 15           Art & Design        June 6, 2018           NaN         4.2
# 16           Art & Design       July 31, 2018           3.1         4.1
# 17           Art & Design    November 7, 2017           1.0         2.3
# 18           Art & Design      August 3, 2018         2.2.5       4.0.3
# 19           Art & Design       July 30, 2018         5.5.4         4.1
# 20           Art & Design      April 20, 2018           4.0         4.1
# 21           Art & Design      March 20, 2018           1.1       4.0.3
# 22           Art & Design       July 12, 2018       2.2.6.2       4.0.3
# 23           Art & Design       March 7, 2018         1.0.0         4.1
# 24           Art & Design        July 7, 2018         1.1.3         4.1
# 25           Art & Design      April 25, 2018           1.5         3.0
# 26           Art & Design    October 11, 2017         1.0.8       4.0.3
# 27           Art & Design      March 21, 2018          1.03       4.0.3
# 28           Art & Design       July 12, 2018           6.0         2.3
# 29           Art & Design     August 22, 2017           1.0         2.3
# ...                   ...                 ...           ...         ...
# 10022           Education      April 10, 2018       1.1.1.6       4.0.3
# 10023        Pretend Play        June 5, 2018         1.0.8         4.1
# 10024           Education      March 15, 2018        1.8.11         4.0
# 10025  Action & Adventure       July 19, 2018           1.0         2.1
# 10026         Brain Games       July 20, 2018         1.2.8         4.1
# 10027        Pretend Play    January 25, 2018         0.0.1         4.1
# 10028           Education       March 5, 2018         1.0.1         4.1
# 10029         Brain Games        June 5, 2018         1.2.7         4.1
# 10030           Education       June 14, 2018         1.0.9         4.0
# 10031        Pretend Play       July 13, 2018           2.6       4.0.3
# 10032         Brain Games      August 7, 2018        1.4.83         4.1
# 10033         Brain Games        July 5, 2018        1.16.0         4.2
# 10034        Pretend Play       July 19, 2018        1.9.10         4.1
# 10035         Brain Games        May 24, 2018           2.0         4.1
# 10036         Brain Games       July 13, 2018           2.3       4.0.3
# 10037        Pretend Play       July 26, 2018         1.0.4         4.1
# 10038        Pretend Play       July 23, 2018         1.1.0         4.1
# 10039  Action & Adventure         May 3, 2016      1.0.3289         4.1
# 10040         Brain Games      April 10, 2016         1.2.2         2.3
# 10041        Pretend Play        June 6, 2018         1.0.9         4.1
# 10042           Education       June 13, 2014           1.2         2.2
# 10043          Creativity      August 7, 2018         1.7.6         4.2
# 10044           Education        May 18, 2017         1.2.2       4.0.3
# 10045          Creativity      August 6, 2018  33.0.0.22.76         4.4
# 10046        Pretend Play   February 10, 2018           5.1         4.2
# 10047           Education        June 6, 2018        1.15.2         4.4
# 10048          Creativity        May 15, 2018           NaN         4.1
# 10049        Pretend Play       July 16, 2018      2.1.3181       4.0.3
# 10050        Pretend Play      April 11, 2018         1.0.5         4.1
# 10051          Creativity       July 23, 2018         2.4.9       4.0.3
#
# [10052 rows x 13 columns]

# %%
col_genres=pd.DataFrame(index = range(0,len(gps4)),columns=new_df['Genres']) #rceates a new dataframe with Genres as columns
col_genres.head()
# Out:
# Genres Art & Design Pretend Play Creativity Action & Adventure  \
# 0               NaN          NaN        NaN                NaN
# 1               NaN          NaN        NaN                NaN
# 2               NaN          NaN        NaN                NaN
# 3               NaN          NaN        NaN                NaN
# 4               NaN          NaN        NaN                NaN
#
# Genres Auto & Vehicles Beauty Books & Reference Business Comics Communication  \
# 0                  NaN    NaN               NaN      NaN    NaN           NaN
# 1                  NaN    NaN               NaN      NaN    NaN           NaN
# 2                  NaN    NaN               NaN      NaN    NaN           NaN
# 3                  NaN    NaN               NaN      NaN    NaN           NaN
# 4                  NaN    NaN               NaN      NaN    NaN           NaN
#
# Genres  ... Photography Travel & Local Tools Personalization Productivity  \
# 0       ...         NaN            NaN   NaN             NaN          NaN
# 1       ...         NaN            NaN   NaN             NaN          NaN
# 2       ...         NaN            NaN   NaN             NaN          NaN
# 3       ...         NaN            NaN   NaN             NaN          NaN
# 4       ...         NaN            NaN   NaN             NaN          NaN
#
# Genres Parenting Weather News & Magazines Maps & Navigation Casino
# 0            NaN     NaN              NaN               NaN    NaN
# 1            NaN     NaN              NaN               NaN    NaN
# 2            NaN     NaN              NaN               NaN    NaN
# 3            NaN     NaN              NaN               NaN    NaN
# 4            NaN     NaN              NaN               NaN    NaN
#
# [5 rows x 53 columns]

# %%
for i in range(0,len(col_genres.columns)):  #fills the entries of col_genres with bool values, True if the column name is equal
    bool=col_genres.columns[i]==gps4['Genres']  #to the entry of Genres in the main df
    col_genres[col_genres.columns[i]]=bool   


col_genres.head()
# Out:
# Genres  Art & Design  Pretend Play  Creativity  Action & Adventure  \
# 0               True         False       False               False
# 1               True         False       False               False
# 2               True         False       False               False
# 3               True         False       False               False
# 4               True         False       False               False
#
# Genres  Auto & Vehicles  Beauty  Books & Reference  Business  Comics  \
# 0                 False   False              False     False   False
# 1                 False   False              False     False   False
# 2                 False   False              False     False   False
# 3                 False   False              False     False   False
# 4                 False   False              False     False   False
#
# Genres  Communication  ...  Photography  Travel & Local  Tools  \
# 0               False  ...        False           False  False
# 1               False  ...        False           False  False
# 2               False  ...        False           False  False
# 3               False  ...        False           False  False
# 4               False  ...        False           False  False
#
# Genres  Personalization  Productivity  Parenting  Weather  News & Magazines  \
# 0                 False         False      False    False             False
# 1                 False         False      False    False             False
# 2                 False         False      False    False             False
# 3                 False         False      False    False             False
# 4                 False         False      False    False             False
#
# Genres  Maps & Navigation  Casino
# 0                   False   False
# 1                   False   False
# 2                   False   False
# 3                   False   False
# 4                   False   False
#
# [5 rows x 53 columns]

# %%
gps_def= pd.concat([gps4, col_genres], axis=1, sort=False) #concatenation
gps_def.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews        Size    Installs  Type Price Content Rating        Genres  \
# 0     159  19000000.0     10000.0  Free     0       Everyone  Art & Design
# 1     967  14000000.0    500000.0  Free     0       Everyone  Art & Design
# 2   87510   8700000.0   5000000.0  Free     0       Everyone  Art & Design
# 3  215644  25000000.0  50000000.0  Free     0           Teen  Art & Design
# 4     967   2800000.0    100000.0  Free     0       Everyone  Art & Design
#
#    ... Photography Travel & Local  Tools  Personalization  Productivity  \
# 0  ...       False          False  False            False         False
# 1  ...       False          False  False            False         False
# 2  ...       False          False  False            False         False
# 3  ...       False          False  False            False         False
# 4  ...       False          False  False            False         False
#
#    Parenting  Weather  News & Magazines  Maps & Navigation  Casino
# 0      False    False             False              False   False
# 1      False    False             False              False   False
# 2      False    False             False              False   False
# 3      False    False             False              False   False
# 4      False    False             False              False   False
#
# [5 rows x 66 columns]

# %% [markdown]
# ### For each genre, compute the average rating. What is the genre with highest average?

# %%
Genre_rating_mean= gps_def.groupby(['Genres'], as_index=False)['Rating'].mean()
Genre_rating_mean.head()
# Out:
#                Genres    Rating
# 0              Action  4.247697
# 1  Action & Adventure  4.288542
# 2           Adventure  4.191026
# 3              Arcade  4.277838
# 4        Art & Design  4.350000

# %% [markdown]
# ### For each app, compute the approximate income, obtain as a product of number of installs and price

# %%
gps_def['Price'] = gps_def.Price.replace('\$','',regex=True)

# %%
gps_def['Price'] = pd.to_numeric(gps_def.Price)

# %%
gps_def['Approximate Income']= gps_def['Price']*gps_def['Installs']

# %% [markdown]
# ### For each app, compute its minimum and maximum Sentiment_polarity

# %%
rev = pd.read_csv("googleplaystore_user_reviews.csv")

# %%
Sent_min_MAX = rev.groupby('App', as_index= False).agg({"Sentiment_Polarity": [min, max]})

# %%
Sent_min_MAX.head()
# Out:
#                                 App Sentiment_Polarity
#                                                    min       max
# 0             10 Best Foods for You            -0.8000  1.000000
# 1  104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室            -0.1125  0.910000
# 2                              11st            -1.0000  1.000000
# 3        1800 Contacts - Lens Store            -0.3000  0.838542
# 4   1LINE – One Line with One Touch            -0.8250  1.000000
